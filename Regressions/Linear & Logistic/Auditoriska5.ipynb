# %%
import pandas as pd

df = pd.read_csv('Salary_dataset.csv')
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30 non-null     int64
#  1   YearsExperience  30 non-null     float64
#  2   Salary           30 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 848.0 bytes

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\jovan\anaconda3\envs\chatbot-env\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\jovan\anaconda3\envs\chatbot-env\lib\site-packages (from seaborn) (2.2.2)
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   Using cached matplotlib-3.9.2-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached contourpy-1.3.0-cp310-cp310-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached fonttools-4.54.1-cp310-cp310-win_amd64.whl.metadata (167 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached kiwisolver-1.4.7-cp310-cp310-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\jovan\anaconda3\envs\chatbot-env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\jovan\anaconda3\envs\chatbot-env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Collecting pyparsing>=2.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached pyparsing-3.2.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jovan\anaconda3\envs\chatbot-env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jovan\anaconda3\envs\chatbot-env\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jovan\anaconda3\envs\chatbot-env\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\jovan\anaconda3\envs\chatbot-env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached matplotlib-3.9.2-cp310-cp310-win_amd64.whl (7.8 MB)
# Using cached contourpy-1.3.0-cp310-cp310-win_amd64.whl (216 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.54.1-cp310-cp310-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.7-cp310-cp310-win_amd64.whl (55 kB)
# Using cached pyparsing-3.2.0-py3-none-any.whl (106 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.54.1 kiwisolver-1.4.7 matplotlib-3.9.2 pyparsing-3.2.0 seaborn-0.13.2

# %%
import seaborn as sns

sns.pairplot(df)

# %%
X=df['YearsExperience']
Y=df['Salary']

# %%
df['YearsExperience'].to_list()
# Out:
# [1.2000000000000002,
#  1.4,
#  1.6,
#  2.1,
#  2.3000000000000003,
#  3.0,
#  3.1,
#  3.3000000000000003,
#  3.3000000000000003,
#  3.8,
#  4.0,
#  4.1,
#  4.1,
#  4.199999999999999,
#  4.6,
#  5.0,
#  5.199999999999999,
#  5.4,
#  6.0,
#  6.1,
#  6.9,
#  7.199999999999999,
#  8.0,
#  8.299999999999999,
#  8.799999999999999,
#  9.1,
#  9.6,
#  9.7,
#  10.4,
#  10.6]

# %%
X.reset_index()
# Out:
#     index  YearsExperience
# 0       0              1.2
# 1       1              1.4
# 2       2              1.6
# 3       3              2.1
# 4       4              2.3
# 5       5              3.0
# 6       6              3.1
# 7       7              3.3
# 8       8              3.3
# 9       9              3.8
# 10     10              4.0
# 11     11              4.1
# 12     12              4.1
# 13     13              4.2
# 14     14              4.6
# 15     15              5.0
# 16     16              5.2
# 17     17              5.4
# 18     18              6.0
# 19     19              6.1
# 20     20              6.9
# 21     21              7.2
# 22     22              8.0
# 23     23              8.3
# 24     24              8.8
# 25     25              9.1
# 26     26              9.6
# 27     27              9.7
# 28     28             10.4
# 29     29             10.6

# %% [markdown]
# [[1.2],[1.4],[1.6],....]

# %%
X.reset_index().drop(['index'],axis=1)
# Out:
#     YearsExperience
# 0               1.2
# 1               1.4
# 2               1.6
# 3               2.1
# 4               2.3
# 5               3.0
# 6               3.1
# 7               3.3
# 8               3.3
# 9               3.8
# 10              4.0
# 11              4.1
# 12              4.1
# 13              4.2
# 14              4.6
# 15              5.0
# 16              5.2
# 17              5.4
# 18              6.0
# 19              6.1
# 20              6.9
# 21              7.2
# 22              8.0
# 23              8.3
# 24              8.8
# 25              9.1
# 26              9.6
# 27              9.7
# 28             10.4
# 29             10.6

# %%
X=X.reset_index().drop(['index'],axis=1)

# %%
from sklearn.model_selection import train_test_split
#80:20
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([9569.58688543])

# %%
model.intercept_
# Out:
# 23437.210463405063

# %% [markdown]
# F(x) = 9569.58688543x + 23437.210463405063

# %%
y_pred = model.predict(X_test)

# %%
df['Salary'].hist()
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_absolute_error, r2_score

print(r2_score(y_test,y_pred)) #0-1
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.8886956733784563
# 6802.779572073899

# %% [markdown]
# #Dataset 2

# %%
df = pd.read_csv('avg-household-size.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3220 entries, 0 to 3219
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   statefips         3220 non-null   int64
#  1   countyfips        3220 non-null   int64
#  2   avghouseholdsize  3220 non-null   float64
#  3   geography         3220 non-null   object
# dtypes: float64(1), int64(2), object(1)
# memory usage: 100.8+ KB

# %%
df.avghouseholdsize.unique()
# Out:
# array([2.43, 3.59, 2.77, 3.86, 2.5 , 2.34, 3.56, 2.69, 2.12, 2.26, 2.62,
#        2.57, 2.55, 2.98, 4.65, 2.9 , 3.03, 3.26, 3.28, 3.97, 2.4 , 2.49,
#        2.15, 3.11, 3.1 , 2.08, 2.32, 2.81, 2.68, 2.6 , 2.61, 2.95, 2.74,
#        2.73, 2.52, 2.44, 2.28, 2.37, 2.45, 2.48, 2.42, 2.56, 2.53, 2.65,
#        2.36, 2.47, 2.7 , 2.27, 2.35, 2.46, 2.54, 2.64, 2.24, 2.72, 2.51,
#        2.59, 2.66, 2.75, 2.86, 2.39, 2.23, 2.31, 2.58, 2.67, 2.33, 2.25,
#        2.41, 2.16, 2.8 , 3.67, 3.02, 2.78, 2.14, 3.08, 2.87, 3.04, 2.3 ,
#        3.06, 2.82, 3.17, 2.92, 3.61, 3.21, 3.19, 3.35, 2.29, 3.32, 2.38,
#        3.24, 2.76, 3.33, 3.16, 2.85, 2.89, 2.63, 3.36, 2.19, 2.21, 2.13,
#        3.78, 2.94, 2.18, 1.91, 2.2 , 2.22, 2.71, 3.  , 2.84, 3.18, 2.17,
#        3.23, 2.05, 3.05, 2.79, 2.97, 3.14, 2.83, 3.12, 2.88, 3.27, 2.99,
#        2.91, 2.96, 1.37, 3.07, 3.22, 3.3 , 2.03, 3.6 , 3.01, 2.09, 2.1 ,
#        2.93, 2.07, 2.01, 2.06, 1.93, 2.11, 3.63, 1.99, 3.54, 1.95, 3.93,
#        2.04, 2.  , 1.97, 1.94, 3.09, 3.84, 3.43, 3.38, 1.86, 3.13, 3.15,
#        3.29, 3.44, 3.41, 3.75, 3.73, 3.37, 1.83, 1.89, 4.73, 3.62, 3.5 ,
#        3.31, 3.42, 3.88, 3.48, 1.98, 3.2 , 3.51, 3.4 , 3.57, 3.25])

# %%
df.geography.unique()
# Out:
# array(['Aleutians East Borough, Alaska',
#        'Aleutians West Census Area, Alaska',
#        'Anchorage Municipality, Alaska', ..., 'Uinta County, Wyoming',
#        'Washakie County, Wyoming', 'Weston County, Wyoming'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df['geography'] = encoder.fit_transform(df['geography'])

# %%
df
# Out:
#       statefips  countyfips  avghouseholdsize  geography
# 0             2          13              2.43         37
# 1             2          16              3.59         38
# 2             2          20              2.77         63
# 3             2          50              3.86        210
# 4             2          60              2.50        282
# ...         ...         ...               ...        ...
# 3215         56          37              2.64       2813
# 3216         56          39              2.63       2849
# 3217         56          41              2.76       2916
# 3218         56          43              2.34       3023
# 3219         56          45              2.27       3101
#
# [3220 rows x 4 columns]

# %%
len(encoder.classes_)
# Out:
# 3220

# %%
df.drop(['avghouseholdsize'],axis=1)
# Out:
#       statefips  countyfips  geography
# 0             2          13         37
# 1             2          16         38
# 2             2          20         63
# 3             2          50        210
# 4             2          60        282
# ...         ...         ...        ...
# 3215         56          37       2813
# 3216         56          39       2849
# 3217         56          41       2916
# 3218         56          43       3023
# 3219         56          45       3101
#
# [3220 rows x 3 columns]

# %%
X = df.drop(['avghouseholdsize'],axis=1)
Y = df.avghouseholdsize

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.1)

# %%
model = LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
X
# Out:
#       statefips  countyfips  geography
# 0             2          13         37
# 1             2          16         38
# 2             2          20         63
# 3             2          50        210
# 4             2          60        282
# ...         ...         ...        ...
# 3215         56          37       2813
# 3216         56          39       2849
# 3217         56          41       2916
# 3218         56          43       3023
# 3219         56          45       3101
#
# [3220 rows x 3 columns]

# %%
model.coef_
# Out:
# array([ 1.18616266e-03,  1.86570914e-04, -5.35960834e-06])

# %%
model.intercept_
# Out:
# 2.4915641301509415

# %%
y_pred = model.predict(X_test)

# %%
mean_absolute_error(Y_test,y_pred)
# Out:
# 0.20228535383892204

# %%
Y.hist()
# Out:
# <Axes: >

# %%
r2_score(Y_test,y_pred)
# Out:
# -5.640796495365308e-05

# %% [markdown]
# #Logistichka regresija

# %%
df = pd.read_csv('abalone.csv')
df.head()
# Out:
#   Type  LongestShell  Diameter  Height  WholeWeight  ShuckedWeight  \
# 0    M         0.455     0.365   0.095       0.5140         0.2245
# 1    M         0.350     0.265   0.090       0.2255         0.0995
# 2    F         0.530     0.420   0.135       0.6770         0.2565
# 3    M         0.440     0.365   0.125       0.5160         0.2155
# 4    I         0.330     0.255   0.080       0.2050         0.0895
#
#    VisceraWeight  ShellWeight  Rings
# 0         0.1010        0.150     15
# 1         0.0485        0.070      7
# 2         0.1415        0.210      9
# 3         0.1140        0.155     10
# 4         0.0395        0.055      7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Type           4177 non-null   object
#  1   LongestShell   4177 non-null   float64
#  2   Diameter       4177 non-null   float64
#  3   Height         4177 non-null   float64
#  4   WholeWeight    4177 non-null   float64
#  5   ShuckedWeight  4177 non-null   float64
#  6   VisceraWeight  4177 non-null   float64
#  7   ShellWeight    4177 non-null   float64
#  8   Rings          4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df['Type'] = encoder.fit_transform(df['Type'])
encoder.classes_
# Out:
# array(['F', 'I', 'M'], dtype=object)

# %%
df.iloc[:,1:]
# Out:
#       LongestShell  Diameter  Height  WholeWeight  ShuckedWeight  \
# 0            0.455     0.365   0.095       0.5140         0.2245
# 1            0.350     0.265   0.090       0.2255         0.0995
# 2            0.530     0.420   0.135       0.6770         0.2565
# 3            0.440     0.365   0.125       0.5160         0.2155
# 4            0.330     0.255   0.080       0.2050         0.0895
# ...            ...       ...     ...          ...            ...
# 4172         0.565     0.450   0.165       0.8870         0.3700
# 4173         0.590     0.440   0.135       0.9660         0.4390
# 4174         0.600     0.475   0.205       1.1760         0.5255
# 4175         0.625     0.485   0.150       1.0945         0.5310
# 4176         0.710     0.555   0.195       1.9485         0.9455
#
#       VisceraWeight  ShellWeight  Rings
# 0            0.1010       0.1500     15
# 1            0.0485       0.0700      7
# 2            0.1415       0.2100      9
# 3            0.1140       0.1550     10
# 4            0.0395       0.0550      7
# ...             ...          ...    ...
# 4172         0.2390       0.2490     11
# 4173         0.2145       0.2605     10
# 4174         0.2875       0.3080      9
# 4175         0.2610       0.2960     10
# 4176         0.3765       0.4950     12
#
# [4177 rows x 8 columns]

# %%
X=df.iloc[:,1:]
Y=df.Type

# %%
df.iloc[:2,5:7]
# Out:
#    ShuckedWeight  VisceraWeight
# 0         0.2245         0.1010
# 1         0.0995         0.0485

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

X_train = scaler.fit_transform(X_train)
#min max Xnorm = Xi-Xmin/Xmax-Xmin
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
Y.unique()
# Out:
# array([2, 0, 1])

# %%
model.coef_
# Out:
# array([[-0.46200279,  1.19417339,  1.27410384,  1.0863727 , -0.78686847,
#          2.45284035,  0.63223653,  1.54853322],
#        [ 2.22103314, -0.26471317, -1.27981623, -2.87740899, -1.23926248,
#         -3.8755724 , -1.29714056, -3.00626006],
#        [-1.75903035, -0.92946022,  0.00571239,  1.79103629,  2.02613096,
#          1.42273205,  0.66490403,  1.45772684]])

# %%
model.intercept_
# Out:
# array([-1.98726946,  2.00592364, -0.01865418])

# %%
model.classes_
# Out:
# array([0, 1, 2])

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import f1_score,classification_report,accuracy_score

f1_score(Y_test,y_pred,average='micro')
# Out:
# 0.5645933014354066

# %%
f1_score(Y_test,y_pred,average='macro')
# Out:
# 0.5489934378823268

# %%
accuracy_score(Y_test,y_pred)
# Out:
# 0.5645933014354066

# %%
print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.45      0.33      0.38       125
#            1       0.65      0.85      0.74       128
#            2       0.54      0.52      0.53       165
#
#     accuracy                           0.56       418
#    macro avg       0.55      0.57      0.55       418
# weighted avg       0.55      0.56      0.55       418

# %%
df = pd.read_csv('abalone.csv')
df.Type
# Out:
# 0       M
# 1       M
# 2       F
# 3       M
# 4       I
#        ..
# 4172    F
# 4173    M
# 4174    M
# 4175    F
# 4176    M
# Name: Type, Length: 4177, dtype: object

# %%
y = encoder.fit_transform(df.Type)

# %%
df['Type'] = y

# %%
encoder.classes_
# Out:
# array(['F', 'I', 'M', nan], dtype=object)

# %%
df.isna().sum()
# Out:
# Type             0
# LongestShell     0
# Diameter         0
# Height           0
# WholeWeight      0
# ShuckedWeight    0
# VisceraWeight    0
# ShellWeight      0
# Rings            0
# dtype: int64

# %%
import numpy as np

df['Type'] = df['Type'].replace(3,np.nan)

# %%
tmp = []

for value in y:
    if value==3:
        tmp.append(np.nan)
    else:
        tmp.append(value)

df['Type'] = tmp

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')
df['Type']  = imputer.fit_transform(df.iloc[:,:1])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Type           4177 non-null   float64
#  1   LongestShell   4177 non-null   float64
#  2   Diameter       4177 non-null   float64
#  3   Height         4177 non-null   float64
#  4   WholeWeight    4177 non-null   float64
#  5   ShuckedWeight  4177 non-null   float64
#  6   VisceraWeight  4177 non-null   float64
#  7   ShellWeight    4177 non-null   float64
#  8   Rings          4177 non-null   int64
# dtypes: float64(8), int64(1)
# memory usage: 293.8 KB
